# %%
#  Masala 0001
a,b = map(int, input().split(' '))
print(a+b)
# Out:
# 25 36
# 61

# %%
#Masala 0002
a,b = map(int, input().split(' '))
print('>' if a>b else '=' if a==b else '<')
# Out:
# 12 3
# >

# %%
#Masala 0003

# %%
#Masala 0004
N,P = map(int, input().split(' '))
print(N*P)
# Out:
# 4 2025
# 8100

# %%
#Masala 0005

# %%
#Masala 0006

# %%
#Masala 0007

# %%
#Masala 0008

# %%
#Masala 0009

# %%
#Masala 0010

# %%
#Masala 0011

# %%
#Masala 0012

# %%
#Masala 0013

# %%
#Masala 0014

# %%
#Masala 0015

# %%
#Masala 0016

# %%
#Masala 0017

# %%
#Masala 0018

# %%
#Masala 0019
N,K = map(int, input().split(' '))
print(int(K//N))
# Out:
# 3 14
# 4

# %%
#Masala 0020
N,K = map(int, input().split(' '))
print(int(K%N))
# Out:
# 3 14
# 2

# %%
#Masala 0021
